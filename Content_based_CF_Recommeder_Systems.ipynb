# %% [markdown]
# <a href="https://colab.research.google.com/github/raodnik/ML/blob/main/Content_based_CF_Recommeder_Systems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
columns_names = ['user_id', 'item_id', 'rating', 'timestamp']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/Movie  dataset/u.data.csv', names =columns_names)

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
columns_names_2 = ['title_id', 'movie_name']

# %%
movie_titles = pd.read_csv('/content/drive/MyDrive/Datasets/Movie  dataset/Movie_Id_Titles')

# %%
movie_titles.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
#merge the item_id and movie_titles
df = pd.merge(df,movie_titles, on = 'item_id')
df.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %%
import seaborn as sns

# %%
sns.set_style('white')

# %%
#Average rating of movie
df.groupby('title')['rating'].mean().sort_values(ascending = False).head()
# Out:
# title
# They Made Me a Criminal (1939)                5.0
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Saint of Fort Washington, The (1993)          5.0
# Someone Else's America (1995)                 5.0
# Star Kid (1997)                               5.0
# Name: rating, dtype: float64

# %%
df.groupby('title')['rating'].count().sort_values(ascending = False).head()
# Out:
# title
# Star Wars (1977)             584
# Contact (1997)               509
# Fargo (1996)                 508
# Return of the Jedi (1983)    507
# Liar Liar (1997)             485
# Name: rating, dtype: int64

# %%
#creating ratings dataframe
ratings = pd.DataFrame(df.groupby('title')['rating'].mean())

# %%
ratings.head()
# Out:
#                              rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390

# %%
ratings['number of ratings'] = pd.DataFrame(df.groupby('title')['rating'].count())

# %%
ratings.head()
# Out:
#                              rating  number of ratings
# title
# 'Til There Was You (1997)  2.333333                  9
# 1-900 (1994)               2.600000                  5
# 101 Dalmatians (1996)      2.908257                109
# 12 Angry Men (1957)        4.344000                125
# 187 (1997)                 3.024390                 41

# %% [markdown]
# #DATA Visualization

# %%
ratings['number of ratings'].hist(bins=70)

# %%
ratings['rating'].hist(bins=70)

# %%
sns.jointplot(x='rating',y = 'number of ratings',data=ratings, alpha = 0.6)
#at 5 we can see a outlier - mostly one or two people rated the movie

# %%
#the useful info in the dataframe is user_id, title and rating. so converting them to matrix form
movie_mat = df.pivot_table(index = 'user_id',columns = 'title',values = 'rating')

# %%
movie_mat.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
#checking out most rated movies
ratings.sort_values('number of ratings', ascending = False).head(10)
# Out:
#                                  rating  number of ratings
# title
# Star Wars (1977)               4.359589                584
# Contact (1997)                 3.803536                509
# Fargo (1996)                   4.155512                508
# Return of the Jedi (1983)      4.007890                507
# Liar Liar (1997)               3.156701                485
# English Patient, The (1996)    3.656965                481
# Scream (1996)                  3.441423                478
# Toy Story (1995)               3.878319                452
# Air Force One (1997)           3.631090                431
# Independence Day (ID4) (1996)  3.438228                429

# %%
#Choosing two movies
starwar_user_ratings = movie_mat['Star Wars (1977)']
liarliar_user_ratings = movie_mat['Liar Liar (1997)']

# %%
similar_to_starwars = movie_mat.corrwith(starwar_user_ratings)
similar_to_liarliar = movie_mat.corrwith(liarliar_user_ratings)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2683: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2542: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
corr_starwars = pd.DataFrame(similar_to_starwars, columns = ['correlations'])

# %%
corr_starwars.head()
# Out:
#                            correlations
# title
# 'Til There Was You (1997)      0.872872
# 1-900 (1994)                  -0.645497
# 101 Dalmatians (1996)          0.211132
# 12 Angry Men (1957)            0.184289
# 187 (1997)                     0.027398

# %%
corr_starwars.isnull()
# Out:
#                                        correlations
# title
# 'Til There Was You (1997)                     False
# 1-900 (1994)                                  False
# 101 Dalmatians (1996)                         False
# 12 Angry Men (1957)                           False
# 187 (1997)                                    False
# ...                                             ...
# Young Guns II (1990)                          False
# Young Poisoner's Handbook, The (1995)         False
# Zeus and Roxanne (1997)                       False
# unknown                                       False
# Á köldum klaka (Cold Fever) (1994)             True
#
# [1664 rows x 1 columns]

# %%
corr_starwars.dropna(inplace = True)

# %%
corr_starwars.head()
# Out:
#                            correlations
# title
# 'Til There Was You (1997)      0.872872
# 1-900 (1994)                  -0.645497
# 101 Dalmatians (1996)          0.211132
# 12 Angry Men (1957)            0.184289
# 187 (1997)                     0.027398

# %%
#there are correlations that make no sense. they are
corr_starwars.sort_values('correlations',ascending = False).head(10)
# Out:
#                                                     correlations
# title
# Hollow Reed (1996)                                           1.0
# Commandments (1997)                                          1.0
# Cosi (1996)                                                  1.0
# No Escape (1994)                                             1.0
# Stripes (1981)                                               1.0
# Star Wars (1977)                                             1.0
# Man of the Year (1995)                                       1.0
# Beans of Egypt, Maine, The (1994)                            1.0
# Old Lady Who Walked in the Sea, The (Vieille qu...           1.0
# Outlaw, The (1943)                                           1.0

# %%
#filter the movie that has number of ratings above 100
corr_starwars = corr_starwars.join(ratings['number of ratings'])
corr_starwars.head()
# Out:
#                            correlations  number of ratings
# title
# 'Til There Was You (1997)      0.872872                  9
# 1-900 (1994)                  -0.645497                  5
# 101 Dalmatians (1996)          0.211132                109
# 12 Angry Men (1957)            0.184289                125
# 187 (1997)                     0.027398                 41

# %%
corr_starwars[corr_starwars['number of ratings']>100].sort_values('correlations',ascending = False).head()
# Out:
#                                                     correlations  \
# title
# Star Wars (1977)                                        1.000000
# Empire Strikes Back, The (1980)                         0.748353
# Return of the Jedi (1983)                               0.672556
# Raiders of the Lost Ark (1981)                          0.536117
# Austin Powers: International Man of Mystery (1997)      0.377433
#
#                                                     number of ratings
# title
# Star Wars (1977)                                                  584
# Empire Strikes Back, The (1980)                                   368
# Return of the Jedi (1983)                                         507
# Raiders of the Lost Ark (1981)                                    420
# Austin Powers: International Man of Mystery (1997)                130

# %%
#now liarliar
corr_liarliar = pd.DataFrame(similar_to_liarliar,columns = ['correlations'])
corr_liarliar.dropna(inplace = True)

# %%
corr_liarliar = corr_liarliar.join(ratings['number of ratings'])

# %%
 corr_liarliar[corr_liarliar['number of ratings']>100].sort_values('correlations',ascending = False).head()
# Out:
#                        correlations  number of ratings
# title
# Liar Liar (1997)           1.000000                485
# Batman Forever (1995)      0.516968                114
# Mask, The (1994)           0.484650                129
# Down Periscope (1996)      0.472681                101
# Con Air (1997)             0.469828                137
